# %% [markdown]
# # Using the basicrobot
# See the project it.unibo.basicrobot2020

# %% [markdown]
# ## Interaction with the basicrobot qactor
# See the model: <a href="../src/basicrobot.qak" target="code">basicrobot.qak</a>.
# <ol>
#     <li>
#         Activate the virtual robot and oper a browser on <tt>localhost:8090</tt>
#     </li>
#     <li>Launch the <tt>basicrobot</tt> as a 'standalone' application (microservice)
# <pre>
# cd C:\..\it.unibo.basicrobot2020-1.0\bin
# it.unibo.basicrobot2020.bat
# </pre>
#     </li>
#     <li>
#         Execute the python code hereunder to move the robot
#     </li>
#     <li>
#         Look at the received data when the (virtual) robot hits an obstacle
#     </li>
# </ol>

# %%
##############################################################
# sendDispatch       : sends a command in output
# read               : acquires data from input
##############################################################
import socket
import time

robotName      = "basicrobot" # robotadapter | basicrobot

hostAdress     = 'localhost'
basicRobotPort = 8018  
  

goForwardMsg  = "msg(cmd,dispatch,python,"+ robotName +",cmd(w),1)"
goBackwardMsg = "msg(cmd,dispatch,python,"+ robotName +",cmd(s),1)" 
turnLeftMsg   = "msg(cmd,dispatch,python,"+ robotName +",cmd(a),1)"  
turnRightMsg  = "msg(cmd,dispatch,python,"+ robotName +",cmd(d),1)"  
haltMsg       = "msg(cmd,dispatch,python,"+ robotName +",cmd(h),1)"
alermEvent    = "msg(alarm,event,python,none,alarm(intruder),1)"

sock          = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

def connect(port) :
    server_address = (hostAdress, port)
    sock.connect(server_address)    
    print("CONNECTED WITH ", server_address )

def send( message ) :
    msg = message + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)

def terminate() :
    read(1) 
    sock.close()    #qak infrastr receives a msg null
    print("BYE")

def read(timeout) :
    sock.settimeout(timeout)
    recStr = ""
    try:
        while( not recStr.endswith("\n") ) :          
            recBytes = sock.recv(1024) # try to receive 1024 bytes
            recStr   = recStr + recBytes.decode('utf8')           
            #print("RECEIVED partial:" , recStr )
        print("RECEIVED:" , recStr )
    except socket.timeout: # fail after 1 second of no activity
        print("no data back ")

def console() :  
    cmd = str(input()) 
    while( cmd != "z" ) :
        if( cmd == "w" ) :
            send( goForwardMsg ) 
        if( cmd == "s" ) :
            send( goBackwardMsg ) 
        if( cmd == "a" ) :
            send( turnLeftMsg ) 
        if( cmd == "d" ) :
            send( turnRightMsg ) 
        if( cmd == "h" ) :
            send( haltMsg ) 
        if( cmd == "m" ) :
            send( alermEvent ) 
        read(1)  
        cmd = str(input())
##################################################
connect(basicRobotPort)
console()
terminate()
# Out:
# CONNECTED WITH  ('localhost', 8018)
# w
# no data back
# h
# no data back
# s
# no data back
# h
# RECEIVED: msg(obstacle,event,filter,none,obstacle(6),222)
# msg(polar,event,forradar,none,polar(6,0),223)
# msg(obstacle,event,filter,none,obstacle(3),229)
# msg(polar,event,forradar,none,polar(3,0),230)
# msg(obstacle,event,filter,none,obstacle(6),237)
# msg(polar,event,forradar,none,polar(6,0),238)
# msg(obstacle,event,filter,none,obstacle(3),245)
# msg(polar,event,forradar,none,polar(3,0),246)
# msg(obstacle,event,filter,none,obstacle(6),253)
# msg(polar,event,forradar,none,polar(6,0),254)
# msg(obstacle,event,filter,none,obstacle(3),261)
# msg(polar,event,forradar,none,polar(3,0),262)
# msg(obstacle,event,filter,none,obstacle(6),269)
# msg(polar,event,forradar,none,polar(6,0),270)
# msg(obstacle,event,filter,none,obstacle(3),277)
# msg(polar,event,forradar,none,polar(3,0),278)
# msg(obstacle,event,filter,none,obstacle(6),285)
# msg(polar,event,forradar,none,polar(6,0),286)
# msg(obstacle,event,filter,none,obstacle(3),293)
# msg(polar,event,forradar,none,polar(3,0),294)
# msg(obstacle,event,filter,none,obstacle(6),301)
# msg(polar,event,forradar,none,polar(6,0),302)
# msg(obstacle,event,filter,none,obstacle(3),309)
# msg(polar,event,forradar,none,polar(3,0),310)
# msg(obstacle,event,filter,none,obstacle(6),317)
# msg(polar,event,forradar,none,polar(6,0),318)
# msg(polar,event,forradar,none,polar(3,0),326)
# msg(obstacle,event,filter,none,obstacle(3),325)
# msg(obstacle,event,filter,none,obstacle(6),333)
# msg(polar,event,forradar,none,polar(6,0),334)
# msg(obstacle,event,filter,none,obstacle(3),341)
# msg(polar,event,forradar,none,polar(3,0),342)
# msg(obstacle,event,filter,none,obstacle(6),349)
# msg(polar,event,forradar,none,polar(6,0),350)
# msg(obstacle,event,filter,none,obstacle(3),357)
# msg(polar,event,forradar,none,polar(3,0),358)
# msg(obstacle,event,filter,none,obstacle(6),365)
# msg(polar,event,forradar,none,polar(6,0),366)
# msg(obstacle,event,filter,none,obstacle(3),373)
# msg(polar,event,forradar,none,polar(3,0),374)
# msg(obstacle,event,filter,none,obstacle(6),381)
# msg(polar,event,forradar,none,polar(6,0),382)
# msg(obstacle,event,filter,none,obstacle(3),389)
# msg(polar,event,forradar,none,polar(3,0),390)
# msg(obstacle,event,filter,none,obstacle(6),397)
# msg(polar,event,forradar,none,polar(6,0),398)
# msg(obstacle,event,filter,none,obstacle(3),405)
# msg(polar,event,forradar,none,polar(3,0),406)
# msg(obstacle,event,filter,none,obstacle(6),413)
# msg(polar,event,forradar,none,polar(6,0),414)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /snap/jupyter/6/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /snap/jupyter/6/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /snap/jupyter/6/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d3505cbab245> in <module>
#      67 ##################################################
#      68 connect(basicRobotPort)
# ---> 69 console()
#      70 terminate()
#
# <ipython-input-4-d3505cbab245> in console()
#      64             send( alermEvent )
#      65         read(1)
# ---> 66         cmd = str(input())
#      67 ##################################################
#      68 connect(basicRobotPort)
#
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:
